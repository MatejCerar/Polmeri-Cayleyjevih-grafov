# %%
import pandas as pd
pd.options.display.max_rows = 20
# %matplotlib inline
import os.path
polmeri = pd.read_csv('polmeri.csv')

# %%
polmeri = polmeri.sort_values(by=['prastevilo', 'polmer'])
polmeri
# Out:
#      prastevilo  polmer  stevilo-ponovitev
# 0             5       6               1163
# 2             5       8                431
# 1             5       9                236
# 3             5      10                170
# 4             7       6                426
# ..          ...     ...                ...
# 223          53      30                  1
# 222          53      31                  1
# 218          53      33                  1
# 221          53      34                  1
# 217          53      39                  2
#
# [224 rows x 3 columns]

# %% [markdown]
# <h2>1. Analiza porazdelitve polmerov </h2>

# %%
polmeri_F5 = polmeri[polmeri["prastevilo"] == 5]
polmeri_F7 = polmeri[polmeri["prastevilo"] == 7]
polmeri_F11 = polmeri[polmeri["prastevilo"] == 11]
polmeri_F13 = polmeri[polmeri["prastevilo"] == 13]
polmeri_F17 = polmeri[polmeri["prastevilo"] == 17]
polmeri_F23 = polmeri[polmeri["prastevilo"] == 23]
polmeri_F29 = polmeri[polmeri["prastevilo"] == 29]
polmeri_F31 = polmeri[polmeri["prastevilo"] == 31]
polmeri_F37 = polmeri[polmeri["prastevilo"] == 37]
polmeri_F41 = polmeri[polmeri["prastevilo"] == 41]
polmeri_F43 = polmeri[polmeri["prastevilo"] == 43]
polmeri_F47 = polmeri[polmeri["prastevilo"] == 47]
polmeri_F53 = polmeri[polmeri["prastevilo"] == 53]


polmeri_F5.plot.bar(x='polmer',y='stevilo-ponovitev',title='F5 porazdelitev polmerov')
polmeri_F7.plot.bar(x='polmer',y='stevilo-ponovitev',title='F7 porazdelitev polmerov')
polmeri_F11.plot.bar(x='polmer',y='stevilo-ponovitev',title='F11 porazdelitev polmerov')
polmeri_F13.plot.bar(x='polmer',y='stevilo-ponovitev',title='F13 porazdelitev polmerov')
polmeri_F17.plot.bar(x='polmer',y='stevilo-ponovitev',title='F17 porazdelitev polmerov')
polmeri_F23.plot.bar(x='polmer',y='stevilo-ponovitev',title='F23 porazdelitev polmerov')
polmeri_F29.plot.bar(x='polmer',y='stevilo-ponovitev',title='F29 porazdelitev polmerov')
polmeri_F31.plot.bar(x='polmer',y='stevilo-ponovitev',title='F31 porazdelitev polmerov')
polmeri_F37.plot.bar(x='polmer',y='stevilo-ponovitev',title='F37 porazdelitev polmerov')
polmeri_F41.plot.bar(x='polmer',y='stevilo-ponovitev',title='F41 porazdelitev polmerov')
polmeri_F43.plot.bar(x='polmer',y='stevilo-ponovitev',title='F43 porazdelitev polmerov')
polmeri_F47.plot.bar(x='polmer',y='stevilo-ponovitev',title='F47 porazdelitev polmerov')
polmeri_F53.plot.bar(x='polmer',y='stevilo-ponovitev',title='F53 porazdelitev polmerov')
# Out:
# <AxesSubplot:title={'center':'F53 porazdelitev polmerov'}, xlabel='polmer'>

# %%
polmeri.plot.scatter('prastevilo','polmer',title='porazdelitev polmerov')
# Out:
# <AxesSubplot:title={'center':'porazdelitev polmerov'}, xlabel='prastevilo', ylabel='polmer'>
